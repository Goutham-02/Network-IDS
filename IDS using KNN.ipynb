# %%
import numpy as np
import pandas as pd

# %%
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty_level"]

# %%
data = pd.read_csv('datasets/KDDTrain+.txt',header=None, names=col_names)

# %%
data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
data.drop(['difficulty_level'],axis=1,inplace=True)

# %%
data.describe()
# Out:
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# ...

# %%
data.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail',
       'snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(data)
# Out:
# C:\Users\gouth\AppData\Local\Temp\ipykernel_3208\2489079628.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)

# %%
data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
data.label.value_counts()
# Out:
# label
# normal    67343
# Dos       45927
# Probe     11656
# R2L         995
# U2R          52
# Name: count, dtype: int64

# %% [markdown]
# Data Normalization

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
numeric_cols = data.select_dtypes(include=[np.number]).columns

# %%
std_scaler = StandardScaler()
def normalization(df,col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
  return df

# %%
data = normalization(data.copy(),numeric_cols)

# %%
data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1      -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2      -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3      -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4      -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
# ...          ...           ...       ...  ...        ...        ...       ...
# 125968 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 125969 -0.107178           udp   private   SF  -0.007744  -0.004883 -0.014089
# 125970 -0.110249           tcp      smtp   SF  -0.007382  -0.004823 -0.014089
# 125971 -0.110249           tcp    klogin   S0  -0.007762  -0.004919 -0.014089
# 125972 -0.110249           tcp  ftp_data   SF  -0.007737  -0.004919 -0.014089
#
# ...

# %% [markdown]
# One Hot encoding

# %%
cat_col = ['protocol_type','service','flag']

# %%
categorical = data[cat_col]
categorical.head()
# Out:
#   protocol_type   service flag
# 0           tcp  ftp_data   SF
# 1           udp     other   SF
# 2           tcp   private   S0
# 3           tcp      http   SF
# 4           tcp      http   SF

# %%
categorical = pd.get_dummies(categorical,columns=cat_col)
categorical.head()
# Out:
#    protocol_type_icmp  protocol_type_tcp  protocol_type_udp  service_IRC  \
# 0               False               True              False        False
# 1               False              False               True        False
# 2               False               True              False        False
# 3               False               True              False        False
# 4               False               True              False        False
#
#    service_X11  service_Z39_50  service_aol  service_auth  service_bgp  \
# 0        False           False        False         False        False
# 1        False           False        False         False        False
# 2        False           False        False         False        False
# 3        False           False        False         False        False
# 4        False           False        False         False        False
#
#    service_courier  ...  flag_REJ  flag_RSTO  flag_RSTOS0  flag_RSTR  flag_S0  \
# ...

# %% [markdown]
# Binary Classification - Normal vs Malicious traffic

# %%
bin_label = pd.DataFrame(data.label.map(lambda x:'normal' if x=='normal' else 'abnormal'))

# %%
bin_data = data.copy()
bin_data['label'] = bin_label

# %%
le1 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le1.fit_transform)
bin_data['intrusion'] = enc_label

# %%
le1.classes_
# Out:
# array(['abnormal', 'normal'], dtype=object)

# %%
np.save("le1_classes.npy",le1.classes_,allow_pickle=True)

# %%
bin_data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0 -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1 -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3 -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4 -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
#
#    wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0       -0.089486 -0.007736 -0.095076  ...               -0.782367
# 1       -0.089486 -0.007736 -0.095076  ...               -1.161030
# 2       -0.089486 -0.007736 -0.095076  ...               -0.938287
# 3       -0.089486 -0.007736 -0.095076  ...                1.066401
# 4       -0.089486 -0.007736 -0.095076  ...                1.066401
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0               -0.280282                     0.069972
# ...

# %%
bin_data = pd.get_dummies(bin_data,columns=['label'],prefix="",prefix_sep="") 
bin_data['label'] = bin_label
bin_data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1      -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2      -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3      -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4      -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
# ...          ...           ...       ...  ...        ...        ...       ...
# 125968 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 125969 -0.107178           udp   private   SF  -0.007744  -0.004883 -0.014089
# 125970 -0.110249           tcp      smtp   SF  -0.007382  -0.004823 -0.014089
# 125971 -0.110249           tcp    klogin   S0  -0.007762  -0.004919 -0.014089
# 125972 -0.110249           tcp  ftp_data   SF  -0.007737  -0.004919 -0.014089
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,8))
plt.pie(bin_data.label.value_counts(),labels=bin_data.label.unique(),autopct='%0.2f%%')
plt.title("Pie chart distribution of normal and abnormal labels")
plt.legend()
plt.savefig('Pie_chart_binary.png')
plt.show()

# %% [markdown]
# Splitting of data into Test & Training data:

# %%
from sklearn.model_selection import train_test_split

# %%
bin_data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1      -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2      -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3      -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4      -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
# ...          ...           ...       ...  ...        ...        ...       ...
# 125968 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 125969 -0.107178           udp   private   SF  -0.007744  -0.004883 -0.014089
# 125970 -0.110249           tcp      smtp   SF  -0.007382  -0.004823 -0.014089
# 125971 -0.110249           tcp    klogin   S0  -0.007762  -0.004919 -0.014089
# 125972 -0.110249           tcp  ftp_data   SF  -0.007737  -0.004919 -0.014089
#
# ...

# %%
#n the intrusion column, 1 -> normal traffic, 0 -> abnormal traffic
bin_data.drop(['label', 'normal', 'abnormal'],axis=1,inplace=True)

# %%
bin_data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1      -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2      -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3      -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4      -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
# ...          ...           ...       ...  ...        ...        ...       ...
# 125968 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 125969 -0.107178           udp   private   SF  -0.007744  -0.004883 -0.014089
# 125970 -0.110249           tcp      smtp   SF  -0.007382  -0.004823 -0.014089
# 125971 -0.110249           tcp    klogin   S0  -0.007762  -0.004919 -0.014089
# 125972 -0.110249           tcp  ftp_data   SF  -0.007737  -0.004919 -0.014089
#
# ...

# %%
W = bin_data.drop(['intrusion', 'protocol_type', 'service', 'flag'], axis=1)
X = bin_data.drop(['intrusion', 'protocol_type', 'service', 'flag'], axis=1).to_numpy()
Y = bin_data['intrusion']

# %%
columns = bin_data.drop(['intrusion', 'protocol_type', 'service', 'flag'], axis=1).columns

# %%
columns
# Out:
# Index(['duration', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment',
#        'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
#        'root_shell', 'su_attempted', 'num_root', 'num_file_creations',
#        'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate'],
#       dtype='object')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.25,stratify=Y,random_state=42)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((94479, 38), (31494, 38), (94479,), (31494,))

# %%
columns.shape
# Out:
# (38,)

# %% [markdown]
# Feature Extraction - HHGS-ROA

# %%
from sklearn.ensemble import RandomForestClassifier
import time

class HHGS_ROA:
    def __init__(self, pop_size=30, max_iter=1, num_features=38):
        self.pop_size = pop_size
        self.max_iter = max_iter
        self.num_features = num_features
        self.speed_rate = 0.1
        self.best_solution = None
        self.best_fitness = float('-inf')
        
    def initialize_population(self):
        print("Initializing population...")
        return np.random.randint(2, size=(self.pop_size, self.num_features))
    
    def fitness_function(self, solution, X_train, X_test, y_train, y_test):
        selected_features = np.where(solution == 1)[0]
        if len(selected_features) == 0:
            return 0.0
        
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train[:, selected_features], y_train)
        y_pred = clf.predict(X_test[:, selected_features])
        
        accuracy = np.mean(y_pred == y_test)
        feature_penalty = 0.01 * len(selected_features) / self.num_features
        return accuracy - feature_penalty
    
    def host_feeding(self, solution, best_solution):
        r = np.random.random()
        new_solution = solution + self.speed_rate * r * (best_solution - solution)
        new_solution = np.round(new_solution).astype(int)
        return np.clip(new_solution, 0, 1)
    
    def free_travel(self, solution):
        new_solution = solution.copy()
        mutation_point = np.random.randint(0, self.num_features)
        new_solution[mutation_point] = 1 - new_solution[mutation_point]
        return new_solution
    
    def optimize(self, X_train, X_test, y_train, y_test, columns):
        start_time = time.time()
        print(f"\nStarting HHGS-ROA optimization with {self.pop_size} agents")
        print(f"Dataset shape: Train {X_train.shape}, Test {X_test.shape}")
        
        population = self.initialize_population()
        
        for t in range(self.max_iter):
            iteration_start = time.time()
            old_best = self.best_fitness
            
            for i in range(self.pop_size):
                current_fitness = self.fitness_function(population[i], X_train, X_test, y_train, y_test)
                
                if current_fitness > self.best_fitness:
                    self.best_fitness = current_fitness
                    self.best_solution = population[i].copy()
                    print(f"\nNew best solution found")
                    print(f"Fitness improved from {old_best:.4f} to {self.best_fitness:.4f}")
                    print(f"Number of selected features: {np.sum(self.best_solution)}")
                
                new_solution = self.host_feeding(population[i], self.best_solution) if np.random.random() < 0.5 else self.free_travel(population[i])
                
                new_fitness = self.fitness_function(new_solution, X_train, X_test, y_train, y_test)
                if new_fitness > current_fitness:
                    population[i] = new_solution
            
            if (t + 1) % 10 == 0:
                elapsed = time.time() - iteration_start
                print(f"\nIteration {t+1}/{self.max_iter} completed in {elapsed:.2f}s")
                print(f"Current best fitness: {self.best_fitness:.4f}")
        
        selected_features = np.where(self.best_solution == 1)[0]
        selected_feature_names = [columns[i] for i in selected_features]
        
        total_time = time.time() - start_time
        print("\nOptimization completed!")
        print(f"Total execution time: {total_time:.2f} seconds")
        print(f"Final number of selected features: {len(selected_features)}")
        print(f"Final fitness score: {self.best_fitness:.4f}")
        
        return selected_feature_names, self.best_fitness

# Usage
optimizer = HHGS_ROA(num_features=len(columns))
selected_features, fitness = optimizer.optimize(X_train, X_test, Y_train, Y_test, columns)
print("\nSelected features:", selected_features)
# Out:
# Starting HHGS-ROA optimization with 30 agents and 1 iterations
# Dataset shape: Train (94479, 38), Test (31494, 38)
# Initializing population...
#
# New best solution found
# Fitness improved from -inf to 0.9920
# Number of selected features: 24
#
# New best solution found
# Fitness improved from -inf to 0.9924
# Number of selected features: 20
#
# New best solution found
# Fitness improved from -inf to 0.9930
# Number of selected features: 20
#
# New best solution found
# Fitness improved from -inf to 0.9936
# Number of selected features: 18
#
# New best solution found
# Fitness improved from -inf to 0.9936
# Number of selected features: 18
#
# Optimization completed!
# Total execution time: 404.15 seconds
# Final number of selected features: 18
# Final fitness score: 0.9936
#
# ...

# %%
selected_features = ['duration',
 'src_bytes',
 'dst_bytes',
 'num_failed_logins',
 'num_access_files',
 'is_guest_login',
 'serror_rate',
 'srv_diff_host_rate',
 'dst_host_count',
 'dst_host_same_srv_rate',
 'dst_host_same_src_port_rate']

# %%
np.save("selected_features.npy",selected_features,allow_pickle=True)

# %%
X_train_df = pd.DataFrame(X_train, columns=columns)
X_test_df = pd.DataFrame(X_test, columns=columns)

# %%
filtered_X_train = X_train_df[selected_features].to_numpy()
filtered_X_test = X_test_df[selected_features].to_numpy()

# %% [markdown]
# Data Training - Support Vector Machine

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# KNN

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(filtered_X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import accuracy_score
y_pred = knn.predict(filtered_X_test)
l_ac = accuracy_score(Y_test, y_pred)*100
print("Linear SVM-Classifier Binary Set-Accuracy is ", l_ac)
# Out:
# Linear SVM-Classifier Binary Set-Accuracy is  97.49476090683939

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.97      0.98      0.97     14658
#       normal       0.98      0.97      0.98     16836
#
#     accuracy                           0.97     31494
#    macro avg       0.97      0.97      0.97     31494
# weighted avg       0.97      0.97      0.97     31494

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:500], label="prediction", linewidth=2.0,color='blue')
plt.plot(Y_test[300:500].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("KNN Binary Classification")
plt.savefig('KNN_real_pred_bin.png')
plt.show()
